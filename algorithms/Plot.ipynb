# %%
import matplotlib.pyplot as plt

# %%
l2 = [0.753036437246964,
0.785425101214575,
0.732793522267207,
0.696356275303644,
0.688259109311741,
0.68421052631579]

l1 = [0.566801619433198,
0.720647773279352,
0.797570850202429,
0.732793522267207,
0.712550607287449,
0.651821862348178
]

# %%
f, ax = plt.subplots()
x = [str(10**i) for i in range(-3, 3)]
ax.plot(x, l1, label='l1 regularization')
ax.plot(x, l2, label='l2 regularization')
ax.set_xlabel('C')
ax.set_ylabel('validation accuracy')

plt.legend()
plt.show()
